# %% [markdown]
# Seaborn is a Python library for data visualization. It’s built on top of Matplotlib and works very well with pandas dataframes.
#
# Seaborn makes it easy to create beautiful charts to explore and understand your data.
#
# Clean and attractive graphs with minimal code
# Built-in themes and color palettes
# Works great with pandas DataFrames
# Includes advanced visualizations like:
# Heatmaps
# Box plots
# Violin plots
# Line plots
# Bar plots
# Scatter plots
# Pair plots
# Regression plots

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Basic Plotting with Seaborn

import seaborn as sns
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Create a Scatter Plot

import matplotlib.pyplot as plt
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Scatter Plot of Total Bill vs Tip")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")
plt.show()

# %%
# Line Plot
sns.lineplot(x ='size', y='total_bill', data= tips)
plt.title("Line Plot of Size vs Total Bill")
# Out:
# Text(0.5, 1.0, 'Line Plot of Size vs Total Bill')

# %%
# Categorical Plot

sns.barplot(x = "day", y = "total_bill", data = tips)
plt.title("Bar Plot of Total Bill by Day")
plt.xlabel("Day of the Week")
plt.ylabel("Total Bill ($)")
# Out:
# Text(0, 0.5, 'Total Bill ($)')

# %%
# Box Plot

sns.boxplot(x='day', y='total_bill', data=tips)
plt.title("Box Plot of Total Bill by Day")
plt.xlabel("Day of the Week")
plt.ylabel("Total Bill ($)")
# Out:
# Text(0, 0.5, 'Total Bill ($)')

# %%
# Violin Plot
sns.violinplot(x='day', y = 'total_bill', data=tips)
plt.title("Violin Plot of Total Bill by Day")
plt.xlabel("Day of the Week")
plt.ylabel("Total Bill ($)")
# Out:
# Text(0, 0.5, 'Total Bill ($)')

# %%
# Histograms

sns.histplot(tips['total_bill'],bins=10, kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# KDE Plot
sns.kdeplot(tips['total_bill'], shade=True)
plt.title("KDE Plot of Total Bill")
plt.xlabel("Total Bill ($)")
plt.ylabel("Density")
plt.show()
# Out:
# /var/folders/nv/_4b4zxj166x1fwmgcz70v0g00000gn/T/ipykernel_28290/2045463835.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'], shade=True)

# %%
# Pair Plot
sns.pairplot(tips)

# %%
#Heatmap

corr = tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Heatmap of Total Bill, Tip, and Size Correlation")
plt.show()
